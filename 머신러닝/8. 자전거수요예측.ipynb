# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore", category=RuntimeWarning)

bike_df = pd.read_csv('./data/train_bike.csv')

print(bike_df.shape)
bike_df.head(3)
# Out:
# (10886, 12)
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32

# %%
# * date : hourly date + timestamp
# * season : 1 = 봄, 2 = 여름, 3 = 가을, 4 = 겨울
# * holiday : 1 = 토, 일요일의 주말을 제외한 국경일 등의 휴일, 0 = 휴일이 아닌날
# * workingday : 1 = 토, 일요일의 주말 및 휴일이 아닌 주중, 0 = 주말 및 휴일
# * weather : 1=맑음, 약간 구름 낀 흐림, 2=안개, 안개 + 흐림, 3=가벼운 눈, 가벼운 비 + 천둥, 4=심한 눈/비, 천둥/번개
# * temp:온도(섭씨)
# * atemp:체감온도(섭씨)
# * humidity:상대습도
# * windspeed:풍속
# * casual:사전에 등록되지 않는 사용자가 대여한 횟수
# * registered:사전에 등록된 사용자가 대여한 횟수
# * count:대여 횟수

# %%
# 문자열을 datetime 타입으로 변경
bike_df['datetime'] = bike_df.datetime.apply(pd.to_datetime)

# datetime 타입에서 년, 월, 일, 시간 추출
bike_df['year'] = bike_df.datetime.apply(lambda x : x.year)
bike_df['month'] = bike_df.datetime.apply(lambda x : x.month)
bike_df['day'] = bike_df.datetime.apply(lambda x : x.day)
bike_df['hour'] = bike_df.datetime.apply(lambda x : x.hour)
bike_df.head(3)
# Out:
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
#
#    humidity  windspeed  casual  registered  count  year  month  day  hour
# 0        81        0.0       3          13     16  2011      1    1     0
# 1        80        0.0       8          32     40  2011      1    1     1
# 2        80        0.0       5          27     32  2011      1    1     2

# %%
bike_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    10886 non-null  datetime64[ns]
#  1   season      10886 non-null  int64
#  2   holiday     10886 non-null  int64
#  3   workingday  10886 non-null  int64
#  4   weather     10886 non-null  int64
#  5   temp        10886 non-null  float64
#  6   atemp       10886 non-null  float64
#  7   humidity    10886 non-null  int64
#  8   windspeed   10886 non-null  float64
#  9   casual      10886 non-null  int64
#  10  registered  10886 non-null  int64
#  11  count       10886 non-null  int64
#  12  year        10886 non-null  int64
#  13  month       10886 non-null  int64
#  14  day         10886 non-null  int64
#  15  hour        10886 non-null  int64
# dtypes: datetime64[ns](1), float64(3), int64(12)
# memory usage: 1.3 MB

# %%
bike_df.describe()
# Out:
#              season       holiday    workingday       weather         temp  \
# count  10886.000000  10886.000000  10886.000000  10886.000000  10886.00000
# mean       2.506614      0.028569      0.680875      1.418427     20.23086
# std        1.116174      0.166599      0.466159      0.633839      7.79159
# min        1.000000      0.000000      0.000000      1.000000      0.82000
# 25%        2.000000      0.000000      0.000000      1.000000     13.94000
# 50%        3.000000      0.000000      1.000000      1.000000     20.50000
# 75%        4.000000      0.000000      1.000000      2.000000     26.24000
# max        4.000000      1.000000      1.000000      4.000000     41.00000
#
#               atemp      humidity     windspeed        casual    registered  \
# count  10886.000000  10886.000000  10886.000000  10886.000000  10886.000000
# mean      23.655084     61.886460     12.799395     36.021955    155.552177
# std        8.474601     19.245033      8.164537     49.960477    151.039033
# min        0.760000      0.000000      0.000000      0.000000      0.000000
# 25%       16.665000     47.000000      7.001500      4.000000     36.000000
# 50%       24.240000     62.000000     12.998000     17.000000    118.000000
# 75%       31.060000     77.000000     16.997900     49.000000    222.000000
# max       45.455000    100.000000     56.996900    367.000000    886.000000
#
#               count          year         month           day          hour
# count  10886.000000  10886.000000  10886.000000  10886.000000  10886.000000
# mean     191.574132   2011.501929      6.521495      9.992559     11.541613
# std      181.144454      0.500019      3.444373      5.476608      6.915838
# min        1.000000   2011.000000      1.000000      1.000000      0.000000
# 25%       42.000000   2011.000000      4.000000      5.000000      6.000000
# 50%      145.000000   2012.000000      7.000000     10.000000     12.000000
# 75%      284.000000   2012.000000     10.000000     15.000000     18.000000
# max      977.000000   2012.000000     12.000000     19.000000     23.000000

# %%
holiday_df = bike_df[bike_df['workingday']!=1]
plt.figure(figsize=(14,8))
sns.boxplot(holiday_df['day'],holiday_df['count'])

# %%
weekday_df = bike_df[bike_df["workingday"]==1]
plt.figure(figsize = (14, 8))
sns.boxplot(weekday_df["day"], weekday_df["count"])

# %%
plt.figure(figsize = (14, 8))
sns.boxplot(bike_df["hour"], bike_df["count"])

# %%
plt.figure(figsize = (14, 8))
sns.boxplot(weekday_df["hour"], weekday_df["count"])

# %%
drop_columns = ['datetime','casual','registered']
bike_df.drop(drop_columns, axis=1,inplace=True)

# %%
fig, axs = plt.subplots(figsize=(16,8), ncols=4, nrows=2)
cat_features=['year', 'month', 'season', 'weather', 'day', 'hour', 'holiday', 'workingday']
# cat_features에 있는 모든 칼럼별로 개별 칼럼값에 따른 count의 합을 barplot으로 시각화
for i, feature in enumerate(cat_features):
    row = int(i/4)
    col = i%4
    #시본의 barplot을 이용해 칼럼값에 따른 count의 합을 표현
    sns.barplot(x=feature, y='count', data=bike_df, ax=axs[row][col])

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

# 타겟 값이 큰 데이터의 영향을 줄이기 위해 log값 사용
# log 값 변환 시 NaN 등의 이슈로 log()가 아닌 log1p()를 이용하여 RMSLE 계산
def rmsle(y, pred):
  log_y = np.log1p(y)
  log_pred = np.log1p(pred)
  squared_error = (log_y - log_pred) ** 2
  rmsle = np.sqrt(np.mean(squared_error))
  return rmsle

# 사이킷런의 mean_square_error()를 이용하여 RMSE 계산
def rmse(y,pred):
  return np.sqrt(mean_squared_error(y, pred))

# MAE, RMSE, RMSLE를 모두 계산
def evaluate_regr(y,pred):
  rmsle_val = rmsle(y,pred)
  rmse_val = rmse(y,pred)
  # MAE는 scikit learn의 mean_absolute_error()로 계산
  mae_val = mean_absolute_error(y, pred)
  print('RMSLE: {0:.3f}, RMSE: {1:.3F}, MAE: {2:.3F}'.format(rmsle_val, rmse_val, mae_val))

# %%
# 학습 데이터, 테스트 데이터 분리
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import LinearRegression, Ridge, Lasso

y_target = bike_df['count']
X_features = bike_df.drop(['count'],axis=1,inplace=False)
print(bike_df)
print('\n')
X_train, X_test, y_train, y_test = train_test_split(X_features, y_target, test_size=0.3, random_state=0)

# 선형회귀 적용 후 학습/예측/평가
lr_reg = LinearRegression()
lr_reg.fit(X_train, y_train)
pred = lr_reg.predict(X_test)

evaluate_regr(y_test,pred)
# Out:
#        season  holiday  workingday  weather   temp   atemp  humidity  \
# 0           1        0           0        1   9.84  14.395        81
# 1           1        0           0        1   9.02  13.635        80
# 2           1        0           0        1   9.02  13.635        80
# 3           1        0           0        1   9.84  14.395        75
# 4           1        0           0        1   9.84  14.395        75
# ...       ...      ...         ...      ...    ...     ...       ...
# 10881       4        0           1        1  15.58  19.695        50
# 10882       4        0           1        1  14.76  17.425        57
# 10883       4        0           1        1  13.94  15.910        61
# 10884       4        0           1        1  13.94  17.425        61
# 10885       4        0           1        1  13.12  16.665        66
#
#        windspeed  count  year  month  day  hour
# 0         0.0000     16  2011      1    1     0
# 1         0.0000     40  2011      1    1     1
# 2         0.0000     32  2011      1    1     2
# 3         0.0000     13  2011      1    1     3
# 4         0.0000      1  2011      1    1     4
# ...          ...    ...   ...    ...  ...   ...
# 10881    26.0027    336  2012     12   19    19
# 10882    15.0013    241  2012     12   19    20
# 10883    15.0013    168  2012     12   19    21
# 10884     6.0032    129  2012     12   19    22
# 10885     8.9981     88  2012     12   19    23
#
# [10886 rows x 13 columns]
#
#
# RMSLE: 1.165, RMSE: 140.900, MAE: 105.924

# %%
def get_top_error_data(y_test, pred, n_tops = 5):
  # DataFrame에 컬럼들로 실제 대여횟수(count)와 예측 값을 서로 비교할 수 있도록 생성
  result_df = pd.DataFrame(y_test.values, columns=['real_count'])
  result_df['predicted_count']= np.round(pred)
  result_df['diff'] = np.abs(result_df['real_count'] - result_df['predicted_count'])
  # 예측값과 실제값이 가장 큰 데이터 순으로 출력
  print(result_df.sort_values('diff', ascending=False)[:n_tops])

get_top_error_data(y_test,pred,n_tops=5)
# Out:
#       real_count  predicted_count   diff
# 1618         890            322.0  568.0
# 3151         798            241.0  557.0
# 966          884            327.0  557.0
# 412          745            194.0  551.0
# 2817         856            310.0  546.0

# %%
y_target.hist()

# %%
y_log_transform = np.log1p(y_target)
y_log_transform.hist()

# %%
#타겟 컬럼인 count값을 log1p로 Log 변환
y_target_log = np.log1p(y_target)

#로그 변환된 y_target_log를  반영하여 학습/테스트 데이터 셋 분할
X_train, X_test, y_train, y_test = train_test_split(X_features, y_target_log, test_size=0.3, random_state=0)
lr_reg = LinearRegression()
lr_reg.fit(X_train, y_train)
pred = lr_reg.predict(X_test)

# 테스트 데이터 셋의 Target 값은 Log 변환되었으므로 다시 expm1를 이용하여 원래 scale로 변환
y_test_exp = np.expm1(y_test)

# 예측 값 역시 Log 변환된 타겟 기반으로 학습되어 예측되었으므로 다시 exmp1으로 scale변환
pred_exp = np.expm1(pred)

evaluate_regr(y_test_exp,pred_exp)
# Out:
# RMSLE: 1.017, RMSE: 162.594, MAE: 109.286

# %%
coef = pd.Series(lr_reg.coef_, index=X_features.columns)
coef_sort = coef.sort_values(ascending=False)
sns.barplot(x=coef_sort.values, y=coef_sort.index)

# %%
# 'year','month','hour','season','weather' feature들을 One Hot Encoding
X_features_ohe = pd.get_dummies(X_features, columns=['year','month','hour','holiday', 
                                                     'workingday','season','weather'])

# %%
# 원-핫 인코딩이 적용된 feature 데이터 세트 기반으로 학습/예측 데이터 분할
X_train, X_test, y_train, y_test = train_test_split(X_features_ohe, y_target_log, 
                                                    test_size=0.3, random_state=0)
# 모델과 학습/테스트 데이터 셋을 입력하면 성능 평가 수치를 변환
def get_model_predict(model, X_train, X_test, y_train, y_test, is_expm1=False):
  model.fit(X_train, y_train)
  pred = model.predict(X_test)
  if is_expm1 :
    y_test = np.expm1(y_test)
    pred = np.expm1(pred)
  print('###',model.__class__.__name__,'###')
  evaluate_regr(y_test, pred)
# end of function get_model_predict

# model별로 평가 수행
lr_reg = LinearRegression()
ridge_reg = Ridge(alpha=10)
lasso_reg = Lasso(alpha=0.01)

for model in [lr_reg, ridge_reg, lasso_reg]:
  get_model_predict(model,X_train, X_test, y_train, y_test,is_expm1=True)
# Out:
# ### LinearRegression ###
# RMSLE: 0.589, RMSE: 97.483, MAE: 63.106
# ### Ridge ###
# RMSLE: 0.589, RMSE: 98.407, MAE: 63.648
# ### Lasso ###
# RMSLE: 0.634, RMSE: 113.031, MAE: 72.658

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
rf_reg = RandomForestRegressor(random_state=0, n_estimators=1000, n_jobs=-1)
gb_reg = GradientBoostingRegressor(random_state=0, n_estimators=1000)
xgb_reg = XGBRegressor(n_estimators=1000, n_jobs=-1)
lgbm_reg = LGBMRegressor(n_estimators=1000, n_jobs=-1)

for model in [rf_reg, gb_reg, xgb_reg, lgbm_reg]:
  get_model_predict(model,X_train, X_test, y_train, y_test,is_expm1=True)
# Out:
# ### RandomForestRegressor ###
# RMSLE: 0.354, RMSE: 50.669, MAE: 31.445
# ### GradientBoostingRegressor ###
# RMSLE: 0.330, RMSE: 51.666, MAE: 31.798
# ### XGBRegressor ###
# RMSLE: 0.341, RMSE: 51.374, MAE: 31.102
# ### LGBMRegressor ###
# RMSLE: 0.320, RMSE: 47.300, MAE: 29.007

# %%
coef = pd.Series(lr_reg.coef_ , index=X_features_ohe.columns)
coef_sort = coef.sort_values(ascending=False)[:10]
sns.barplot(x=coef_sort.values , y=coef_sort.index)

# %%
from pycaret.regression import *

# %%
X_train, X_test, y_train, y_test = train_test_split(X_features, y_target, test_size=0.3, random_state=0)

# %%
s = setup(bike_df, target='count')

best = compare_models()

# evaluate_model(best)
# Out:
# <style type="text/css">
# #T_cbcc1_ th {
#   text-align: left;
# }
# #T_cbcc1_row0_col0, #T_cbcc1_row0_col5, #T_cbcc1_row0_col6, #T_cbcc1_row1_col0, #T_cbcc1_row1_col1, #T_cbcc1_row1_col2, #T_cbcc1_row1_col3, #T_cbcc1_row1_col4, #T_cbcc1_row1_col5, #T_cbcc1_row1_col6, #T_cbcc1_row2_col0, #T_cbcc1_row2_col1, #T_cbcc1_row2_col2, #T_cbcc1_row2_col3, #T_cbcc1_row2_col4, #T_cbcc1_row3_col0, #T_cbcc1_row3_col1, #T_cbcc1_row3_col2, #T_cbcc1_row3_col3, #T_cbcc1_row3_col4, #T_cbcc1_row3_col5, #T_cbcc1_row3_col6, #T_cbcc1_row4_col0, #T_cbcc1_row4_col1, #T_cbcc1_row4_col2, #T_cbcc1_row4_col3, #T_cbcc1_row4_col4, #T_cbcc1_row4_col5, #T_cbcc1_row4_col6, #T_cbcc1_row5_col0, #T_cbcc1_row5_col1, #T_cbcc1_row5_col2, #T_cbcc1_row5_col3, #T_cbcc1_row5_col4, #T_cbcc1_row5_col5, #T_cbcc1_row5_col6, #T_cbcc1_row6_col0, #T_cbcc1_row6_col1, #T_cbcc1_row6_col2, #T_cbcc1_row6_col3, #T_cbcc1_row6_col4, #T_cbcc1_row6_col5, #T_cbcc1_row6_col6, #T_cbcc1_row7_col0, #T_cbcc1_row7_col1, #T_cbcc1_row7_col2, #T_cbcc1_row7_col3, #T_cbcc1_row7_col4, #T_cbcc1_row7_col5, #T_cbcc1_row7_col6, #T_cbcc1_row8_col0, #T_cbcc1_row8_col1, #T_cbcc1_row8_col2, #T_cbcc1_row8_col3, #T_cbcc1_row8_col4, #T_cbcc1_row8_col5, #T_cbcc1_row8_col6, #T_cbcc1_row9_col0, #T_cbcc1_row9_col1, #T_cbcc1_row9_col2, #T_cbcc1_row9_col3, #T_cbcc1_row9_col4, #T_cbcc1_row9_col5, #T_cbcc1_row9_col6, #T_cbcc1_row10_col0, #T_cbcc1_row10_col1, #T_cbcc1_row10_col2, #T_cbcc1_row10_col3, #T_cbcc1_row10_col4, #T_cbcc1_row10_col5, #T_cbcc1_row10_col6, #T_cbcc1_row11_col0, #T_cbcc1_row11_col1, #T_cbcc1_row11_col2, #T_cbcc1_row11_col3, #T_cbcc1_row11_col4, #T_cbcc1_row11_col5, #T_cbcc1_row11_col6, #T_cbcc1_row12_col0, #T_cbcc1_row12_col1, #T_cbcc1_row12_col2, #T_cbcc1_row12_col3, #T_cbcc1_row12_col4, #T_cbcc1_row12_col5, #T_cbcc1_row12_col6, #T_cbcc1_row13_col0, #T_cbcc1_row13_col1, #T_cbcc1_row13_col2, #T_cbcc1_row13_col3, #T_cbcc1_row13_col4, #T_cbcc1_row13_col5, #T_cbcc1_row13_col6, #T_cbcc1_row14_col0, #T_cbcc1_row14_col1, #T_cbcc1_row14_col2, #T_cbcc1_row14_col3, #T_cbcc1_row14_col4, #T_cbcc1_row14_col5, #T_cbcc1_row14_col6, #T_cbcc1_row15_col0, #T_cbcc1_row15_col1, #T_cbcc1_row15_col2, #T_cbcc1_row15_col3, #T_cbcc1_row15_col4, #T_cbcc1_row15_col5, #T_cbcc1_row15_col6, #T_cbcc1_row16_col0, #T_cbcc1_row16_col1, #T_cbcc1_row16_col2, #T_cbcc1_row16_col3, #T_cbcc1_row16_col4, #T_cbcc1_row16_col5, #T_cbcc1_row16_col6, #T_cbcc1_row17_col0, #T_cbcc1_row17_col1, #T_cbcc1_row17_col2, #T_cbcc1_row17_col3, #T_cbcc1_row17_col4, #T_cbcc1_row17_col5, #T_cbcc1_row17_col6, #T_cbcc1_row18_col0, #T_cbcc1_row18_col1, #T_cbcc1_row18_col2, #T_cbcc1_row18_col3, #T_cbcc1_row18_col4, #T_cbcc1_row18_col5, #T_cbcc1_row18_col6 {
#   text-align: left;
# }
# #T_cbcc1_row0_col1, #T_cbcc1_row0_col2, #T_cbcc1_row0_col3, #T_cbcc1_row0_col4, #T_cbcc1_row2_col5, #T_cbcc1_row2_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_cbcc1_row0_col7, #T_cbcc1_row1_col7, #T_cbcc1_row2_col7, #T_cbcc1_row3_col7, #T_cbcc1_row4_col7, #T_cbcc1_row5_col7, #T_cbcc1_row6_col7, #T_cbcc1_row7_col7, #T_cbcc1_row8_col7, #T_cbcc1_row10_col7, #T_cbcc1_row11_col7, #T_cbcc1_row12_col7, #T_cbcc1_row13_col7, #T_cbcc1_row14_col7, #T_cbcc1_row15_col7, #T_cbcc1_row16_col7, #T_cbcc1_row17_col7, #T_cbcc1_row18_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_cbcc1_row9_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_cbcc1_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >MAE</th>
#       <th class="col_heading level0 col2" >MSE</th>
#       <th class="col_heading level0 col3" >RMSE</th>
#       <th class="col_heading level0 col4" >R2</th>
#       <th class="col_heading level0 col5" >RMSLE</th>
#       <th class="col_heading level0 col6" >MAPE</th>
#       <th class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cbcc1_level0_row0" class="row_heading level0 row0" >lightgbm</th>
#       <td id="T_cbcc1_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_cbcc1_row0_col1" class="data row0 col1" >27.7466</td>
#       <td id="T_cbcc1_row0_col2" class="data row0 col2" >1862.8218</td>
#       <td id="T_cbcc1_row0_col3" class="data row0 col3" >43.0299</td>
#       <td id="T_cbcc1_row0_col4" class="data row0 col4" >0.9433</td>
#       <td id="T_cbcc1_row0_col5" class="data row0 col5" >0.4219</td>
#       <td id="T_cbcc1_row0_col6" class="data row0 col6" >0.4374</td>
#       <td id="T_cbcc1_row0_col7" class="data row0 col7" >0.0330</td>
#     </tr>
#     <tr>
#       <th id="T_cbcc1_level0_row1" class="row_heading level0 row1" >xgboost</th>
#       <td id="T_cbcc1_row1_col0" class="data row1 col0" >Extreme Gradient Boosting</td>
#       <td id="T_cbcc1_row1_col1" class="data row1 col1" >28.1041</td>
#       <td id="T_cbcc1_row1_col2" class="data row1 col2" >1867.5672</td>
#       <td id="T_cbcc1_row1_col3" class="data row1 col3" >43.1486</td>
#       <td id="T_cbcc1_row1_col4" class="data row1 col4" >0.9430</td>
#       <td id="T_cbcc1_row1_col5" class="data row1 col5" >0.4568</td>
#       <td id="T_cbcc1_row1_col6" class="data row1 col6" >0.4538</td>
#       <td id="T_cbcc1_row1_col7" class="data row1 col7" >0.1940</td>
#     </tr>
#     <tr>
#       <th id="T_cbcc1_level0_row2" class="row_heading level0 row2" >et</th>
#       <td id="T_cbcc1_row2_col0" class="data row2 col0" >Extra Trees Regressor</td>
#       <td id="T_cbcc1_row2_col1" class="data row2 col1" >28.2160</td>
#       <td id="T_cbcc1_row2_col2" class="data row2 col2" >1981.7758</td>
#       <td id="T_cbcc1_row2_col3" class="data row2 col3" >44.3458</td>
#       <td id="T_cbcc1_row2_col4" class="data row2 col4" >0.9397</td>
#       <td id="T_cbcc1_row2_col5" class="data row2 col5" >0.3582</td>
#       <td id="T_cbcc1_row2_col6" class="data row2 col6" >0.3345</td>
#       <td id="T_cbcc1_row2_col7" class="data row2 col7" >0.5050</td>
#     </tr>
#     <tr>
#       <th id="T_cbcc1_level0_row3" class="row_heading level0 row3" >rf</th>
#       <td id="T_cbcc1_row3_col0" class="data row3 col0" >Random Forest Regressor</td>
#       <td id="T_cbcc1_row3_col1" class="data row3 col1" >28.9446</td>
#       <td id="T_cbcc1_row3_col2" class="data row3 col2" >2144.7767</td>
#       <td id="T_cbcc1_row3_col3" class="data row3 col3" >46.2167</td>
#       <td id="T_cbcc1_row3_col4" class="data row3 col4" >0.9346</td>
#       <td id="T_cbcc1_row3_col5" class="data row3 col5" >0.3668</td>
#       <td id="T_cbcc1_row3_col6" class="data row3 col6" >0.3452</td>
#       <td id="T_cbcc1_row3_col7" class="data row3 col7" >0.4480</td>
#     </tr>
#     <tr>
#       <th id="T_cbcc1_level0_row4" class="row_heading level0 row4" >dt</th>
#       <td id="T_cbcc1_row4_col0" class="data row4 col0" >Decision Tree Regressor</td>
#       <td id="T_cbcc1_row4_col1" class="data row4 col1" >38.3080</td>
#       <td id="T_cbcc1_row4_col2" class="data row4 col2" >4036.9156</td>
#       <td id="T_cbcc1_row4_col3" class="data row4 col3" >63.4272</td>
#       <td id="T_cbcc1_row4_col4" class="data row4 col4" >0.8770</td>
#       <td id="T_cbcc1_row4_col5" class="data row4 col5" >0.4701</td>
#       <td id="T_cbcc1_row4_col6" class="data row4 col6" >0.4147</td>
#       <td id="T_cbcc1_row4_col7" class="data row4 col7" >0.0230</td>
#     </tr>
#     <tr>
#       <th id="T_cbcc1_level0_row5" class="row_heading level0 row5" >gbr</th>
#       <td id="T_cbcc1_row5_col0" class="data row5 col0" >Gradient Boosting Regressor</td>
#       <td id="T_cbcc1_row5_col1" class="data row5 col1" >47.7885</td>
#       <td id="T_cbcc1_row5_col2" class="data row5 col2" >4906.7056</td>
#       <td id="T_cbcc1_row5_col3" class="data row5 col3" >69.9983</td>
#       <td id="T_cbcc1_row5_col4" class="data row5 col4" >0.8507</td>
#       <td id="T_cbcc1_row5_col5" class="data row5 col5" >0.6657</td>
#       <td id="T_cbcc1_row5_col6" class="data row5 col6" >0.9259</td>
#       <td id="T_cbcc1_row5_col7" class="data row5 col7" >0.1180</td>
#     </tr>
#     <tr>
#       <th id="T_cbc
